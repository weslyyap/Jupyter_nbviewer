# %%
#Initialization

import numpy as np
import pandas as pd
import os
import re
#os.getcwd()

# %%
#Build a recommendation system based on ratings from users
file_path = 'C:/Users/User/Machine Learning/Movie_Rank_Recommendation_Lite/ratings_lite.csv'
ratings = pd.read_csv(file_path)

#Make sure movie id is string for primary key to join df
ratings['movieId'] = ratings['movieId'].astype(str)
ratings.head(5)
# Out:
#    userId movieId  rating
# 0       1     296     5.0
# 1       1     306     3.5
# 2       1     307     5.0
# 3       1     665     5.0
# 4       1     899     3.5

# %%
file_path1 = 'C:/Users/User/Machine Learning/Movie_Rank_Recommendation_Lite/movies.csv'
movie = pd.read_csv(file_path1)
movie['movieId'] = movie['movieId'].astype(str)
#movie = movie.merge(ratings, how = 'inner', on = 'movieId')
movie
# Out:
#       movieId                               title  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 3           4            Waiting to Exhale (1995)
# 4           5  Father of the Bride Part II (1995)
# ...       ...                                 ...
# 62418  209157                           We (2018)
# 62419  209159           Window of the Soul (2001)
# 62420  209163                    Bad Poems (2018)
# 62421  209169                 A Girl Thing (2001)
# 62422  209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
# [62423 rows x 3 columns]

# %%
#Clean the title of the movies
def clean_title(title):
    return re.sub("[^a-zA-Z0-9 ]", "", title)

# %%
movie["clean_title"] = movie["title"].apply(clean_title)
movie.head(5)
# Out:
#   movieId                               title  \
# 0       1                    Toy Story (1995)
# 1       2                      Jumanji (1995)
# 2       3             Grumpier Old Men (1995)
# 3       4            Waiting to Exhale (1995)
# 4       5  Father of the Bride Part II (1995)
#
#                                         genres  \
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#
#                         clean_title
# 0                    Toy Story 1995
# 1                      Jumanji 1995
# 2             Grumpier Old Men 1995
# 3            Waiting to Exhale 1995
# 4  Father of the Bride Part II 1995

# %%
#Generate a list of watched movie
mymovie = movie.sample(n = 520)
movie_set = set(mymovie['movieId'])

# %%
#Find similar users
overlap_users = {}
for i in range(ratings.shape[0]):
    if ratings['movieId'][i] in movie_set:
        if ratings['userId'][i] not in overlap_users:
            overlap_users[ratings['userId'][i]] = 1
        else:
            overlap_users[ratings['userId'][i]] += 1

# %%
len(overlap_users)
# Out:
# 2847

# %%
#Further find only users who have read some of the same books (more than 5%) as us
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k] > len(movie_set)*0.05])
filtered_overlap_users
# Out:
# {847, 997, 1748, 2177, 5114}

# %%
#Get the movie id and ratings from the overlap users
interactions = ratings[(ratings["userId"].isin(filtered_overlap_users))][["userId", "movieId", "rating"]]
interactions
# Out:
#         userId movieId  rating
# 113099     847       1     4.0
# 113100     847       6     4.5
# 113101     847       7     3.0
# 113102     847      10     2.5
# 113103     847      16     2.5
# ...        ...     ...     ...
# 753127    5114  204542     2.5
# 753128    5114  204692     1.5
# 753129    5114  204698     2.0
# 753130    5114  205279     3.0
# 753131    5114  207405     3.0
#
# [15370 rows x 3 columns]

# %%
#Get my movie ratings
my_movie_ratings = ratings[(ratings["movieId"].isin(movie_set))][["movieId", "rating"]]
myuserId = pd.Series(-1, index = range(len(my_movie_ratings)))
my_movie_ratings = my_movie_ratings.merge(myuserId.rename("userId"), left_index = True, right_index = True)
my_movie_ratings = my_movie_ratings.reindex(columns = ['userId', 'movieId', 'rating'])
my_movie_ratings.head(5)
# Out:
#      userId movieId  rating
# 62       -1    8786     4.0
# 175      -1    3114     4.5
# 245      -1   31923     3.5
# 780      -1   95441     3.5
# 830      -1  110102     4.0

# %%
#Adding own movie ratings into the ratings list
interactions = pd.concat([my_movie_ratings[["userId", "movieId", "rating"]], interactions])
interactions['userId'] = interactions['userId'].astype(str)
interactions['movieId'] = interactions['movieId'].astype(str)
interactions['rating'] = pd.to_numeric(interactions['rating'])

# %%
#Want each user id to correspond to single row in the collaboration filter matrix
#Assigne a number to each category (user id AND movie id)
interactions['user_index'] = interactions['userId'].astype('category').cat.codes
interactions['movie_index'] = interactions['movieId'].astype('category').cat.codes

# %%
from scipy.sparse import coo_matrix
import scipy.sparse as sparse

#Memory efficient using sparse matrix
ratings_mat_coo = coo_matrix((interactions['rating'], (interactions['user_index'], interactions['movie_index'])))
ratings_mat_coo
# Out:
# <6x8909 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15409 stored elements in COOrdinate format>

# %%
ratings_mat = ratings_mat_coo.tocsr()
print(ratings_mat.toarray())
# Out:
# [[0.  0.  0.  ... 0.  0.  0. ]
#  [4.5 4.5 3.  ... 0.  0.  0. ]
#  [4.  4.  4.  ... 0.  0.  0. ]
#  [3.5 0.  0.  ... 2.5 0.  0. ]
#  [4.  2.5 3.5 ... 4.5 0.  0. ]
#  [4.5 3.  0.  ... 0.  3.5 3. ]]

# %%
interactions[interactions['userId'] == '-1']
# Out:
#      userId movieId  rating  user_index  movie_index
# 62       -1    8786     4.0           0         8327
# 175      -1    3114     4.5           0         3618
# 245      -1   31923     3.5           0         3724
# 780      -1   95441     3.5           0         8758
# 830      -1  110102     4.0           0          349
# 841      -1  112370     3.0           0          412
# 864      -1  122906     4.0           0          680
# 904      -1  176101     3.5           0         1894
# 950      -1    3114     3.0           0         3618
# 1030     -1   72226     4.0           0         7400
# 1036     -1   76175     1.5           0         7658
# 1098     -1  110102     3.5           0          349
# 1138     -1  176101     3.0           0         1894
# 1147     -1  195159     5.0           0         2307
# 1342     -1     290     4.0           0         3416
# 1388     -1     903     4.0           0         8542
# 2046     -1    2112     4.0           0         2524
# 2296     -1    5380     3.5           0         5855
# 2396     -1   41712     3.5           0         4677
# 2443     -1   72226     3.5           0         7400
# 2760     -1   55908     4.0           0         6078
# 2816     -1   72226     4.5           0         7400
# 2830     -1   76175     4.0           0         7658
# 3157     -1    3114     3.0           0         3618
# 3281     -1    2411     3.5           0         2756
# 3445     -1   40414     3.5           0         4553
# 3600     -1  110102     1.5           0          349
# 3787     -1   55908     5.0           0         6078
# 4084     -1    1835     4.0           0         2052
# 4122     -1    2112     5.0           0         2524
# 4166     -1    2411     3.0           0         2756
# 5568     -1     903     4.5           0         8542
# 5669     -1     533     3.0           0         5812
# 5777     -1    2411     2.0           0         2756
# 6259     -1   47516     2.5           0         5231
# 6319     -1   95441     4.5           0         8758
# 6391     -1     903     4.5           0         8542
# 6523     -1    8492     3.0           0         8117
# 6566     -1     290     3.0           0         3416

# %%
my_index = 0

# %%
#Quantify how similar the other users to us
#Get movie recommendations from them (collaborating with similar users)
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()
similarity
# Out:
# array([1.        , 0.03400318, 0.03237031, 0.04827243, 0.03846844,
#        0.05977109])

# %%
#Get user id for the users most similar to us
if (len(similarity) - 1) % 2 == 0:
    number = len(similarity - 1)
else:
    number = len(similarity)
display(number)
#indices = np.argpartition(similarity, -1*(number / 2))[(number / 2):]
#n users that are most similar to us
round_num = round(number/2)
indices = np.argpartition(similarity, -round_num)[round_num:]

similar_users = interactions[interactions['user_index'].isin(indices)].copy()
similar_users = similar_users[similar_users['userId'] != '-1']
# Out:
# 6

# %%
indices
# Out:
# array([3, 5, 0], dtype=int64)

# %%
interactions
# Out:
#        userId movieId  rating  user_index  movie_index
# 62         -1    8786     4.0           0         8327
# 175        -1    3114     4.5           0         3618
# 245        -1   31923     3.5           0         3724
# 780        -1   95441     3.5           0         8758
# 830        -1  110102     4.0           0          349
# ...       ...     ...     ...         ...          ...
# 753127   5114  204542     2.5           3         2459
# 753128   5114  204692     1.5           3         2461
# 753129   5114  204698     2.0           3         2462
# 753130   5114  205279     3.0           3         2472
# 753131   5114  207405     3.0           3         2489
#
# [15409 rows x 5 columns]

# %%
similar_users
# Out:
#        userId movieId  rating  user_index  movie_index
# 140679    997       1     4.5           5            0
# 140680    997       2     3.5           5         2389
# 140681    997       5     3.0           5         5500
# 140682    997       6     4.5           5         6396
# 140683    997      10     3.0           5            1
# ...       ...     ...     ...         ...          ...
# 753127   5114  204542     2.5           3         2459
# 753128   5114  204692     1.5           3         2461
# 753129   5114  204698     2.0           3         2462
# 753130   5114  205279     3.0           3         2472
# 753131   5114  207405     3.0           3         2489
#
# [5030 rows x 5 columns]

# %%
#Find how many times each movies appear in this recommendation and the its mean rating
movie_recs = similar_users.groupby('movieId').rating.agg(['count' , 'mean'])
movie_recs
# Out:
#          count  mean
# movieId
# 1            2   4.0
# 10           1   3.0
# 100044       1   3.5
# 100075       1   3.5
# 100083       2   2.5
# ...        ...   ...
# 99910        1   3.0
# 99912        1   2.0
# 99917        1   2.5
# 99957        1   3.5
# 99992        1   3.0
#
# [4002 rows x 2 columns]

# %%
#Get movie title to the recommendation list
movie_recs = movie_recs.merge(movie, how = 'inner', on = 'movieId')
movie_recs
# Out:
#      movieId  count  mean                   title  \
# 0          1      2   4.0        Toy Story (1995)
# 1         10      1   3.0        GoldenEye (1995)
# 2     100044      1   3.5     Human Planet (2011)
# 3     100075      1   3.5           Choose (2010)
# 4     100083      2   2.5         Movie 43 (2013)
# ...      ...    ...   ...                     ...
# 3997   99910      1   3.0  Last Stand, The (2013)
# 3998   99912      1   2.0             Mama (2013)
# 3999   99917      1   2.5   Upstream Color (2013)
# 4000   99957      1   3.5      Broken City (2013)
# 4001   99992      1   3.0    Shadow Dancer (2012)
#
#                                            genres          clean_title
# 0     Adventure|Animation|Children|Comedy|Fantasy       Toy Story 1995
# 1                       Action|Adventure|Thriller       GoldenEye 1995
# 2                                     Documentary    Human Planet 2011
# 3                              Crime|Drama|Horror          Choose 2010
# 4                                          Comedy        Movie 43 2013
# ...                                           ...                  ...
# 3997                        Action|Crime|Thriller  Last Stand The 2013
# 3998                                       Horror            Mama 2013
# 3999                      Romance|Sci-Fi|Thriller  Upstream Color 2013
# 4000                         Crime|Drama|Thriller     Broken City 2013
# 4001                         Crime|Drama|Thriller   Shadow Dancer 2012
#
# [4002 rows x 6 columns]

# %%
#Find the number of times a movie is rated
total_ratings_per_movie = ratings.groupby('movieId').rating.agg(['count'])
total_ratings_per_movie.head(5)
# Out:
#          count
# movieId
# 1         2465
# 10        1173
# 100        162
# 1000        10
# 100008       1

# %%
total_ratings_per_movie.shape
# Out:
# (22240, 1)

# %%
movie_recs = movie_recs.merge(total_ratings_per_movie, how = 'inner', on = 'movieId')
movie_recs.rename(columns={'count_x': 'count', 'count_y': 'rating'}, inplace = True)
movie_recs
# Out:
#      movieId  count  mean                   title  \
# 0          1      2   4.0        Toy Story (1995)
# 1         10      1   3.0        GoldenEye (1995)
# 2     100044      1   3.5     Human Planet (2011)
# 3     100075      1   3.5           Choose (2010)
# 4     100083      2   2.5         Movie 43 (2013)
# ...      ...    ...   ...                     ...
# 3997   99910      1   3.0  Last Stand, The (2013)
# 3998   99912      1   2.0             Mama (2013)
# 3999   99917      1   2.5   Upstream Color (2013)
# 4000   99957      1   3.5      Broken City (2013)
# 4001   99992      1   3.0    Shadow Dancer (2012)
#
#                                            genres          clean_title  rating
# 0     Adventure|Animation|Children|Comedy|Fantasy       Toy Story 1995    2465
# 1                       Action|Adventure|Thriller       GoldenEye 1995    1173
# 2                                     Documentary    Human Planet 2011      20
# 3                              Crime|Drama|Horror          Choose 2010       1
# 4                                          Comedy        Movie 43 2013      34
# ...                                           ...                  ...     ...
# 3997                        Action|Crime|Thriller  Last Stand The 2013      33
# 3998                                       Horror            Mama 2013      51
# 3999                      Romance|Sci-Fi|Thriller  Upstream Color 2013      29
# 4000                         Crime|Drama|Thriller     Broken City 2013      10
# 4001                         Crime|Drama|Thriller   Shadow Dancer 2012       1
#
# [4002 rows x 7 columns]

# %%
#Ranking recommendations
movie_recs['adjusted_count'] = movie_recs['count'] * (movie_recs['count'] / movie_recs['rating'])

# %%
movie_recs['score'] = movie_recs['mean'] * movie_recs['adjusted_count']
#Take out any movie we have already watched
movie_recs = movie_recs[~movie_recs['movieId'].isin(mymovie['movieId'])]
#Take out any movie title too because this is not the cleanest data, different movies might have the same movie id
movie_recs = movie_recs[~movie_recs['clean_title'].isin(mymovie['clean_title'])]
#At least 2 users who are similar to us had watch the movie and like it in order to put into the movie reco list
movie_recs = movie_recs[movie_recs['count'] > 1]
movie_recs = movie_recs[movie_recs['mean'] > 3]

top_movie_recs = movie_recs.sort_values('score', ascending = False)
top_movie_recs
# Out:
#      movieId  count  mean                                      title  \
# 3177   68288      2  3.75                      Informers, The (2008)
# 3245   70015      2  3.25                       Polytechnique (2009)
# 1015  168288      2  3.25                The Belko Experiment (2017)
# 233   111235      2  4.25                   Jodorowsky's Dune (2013)
# 3977   98239      2  3.25                            Red Dawn (2012)
# ...      ...    ...   ...                                        ...
# 213      110      2  3.50                          Braveheart (1995)
# 1774     260      2  4.00  Star Wars: Episode IV - A New Hope (1977)
# 1927     296      2  4.00                        Pulp Fiction (1994)
# 2127     356      2  3.75                        Forrest Gump (1994)
# 2001     318      2  3.50           Shawshank Redemption, The (1994)
#
#                            genres                            clean_title  \
# 3177         Crime|Drama|Thriller                     Informers The 2008
# 3245                  Crime|Drama                     Polytechnique 2009
# 1015       Action|Horror|Thriller              The Belko Experiment 2017
# 233            Documentary|Sci-Fi                  Jodorowskys Dune 2013
# 3977                   Action|War                          Red Dawn 2012
# ...                           ...                                    ...
# 213              Action|Drama|War                        Braveheart 1995
# 1774      Action|Adventure|Sci-Fi  Star Wars Episode IV  A New Hope 1977
# 1927  Comedy|Crime|Drama|Thriller                      Pulp Fiction 1994
# 2127     Comedy|Drama|Romance|War                      Forrest Gump 1994
# 2001                  Crime|Drama          Shawshank Redemption The 1994
#
#       rating  adjusted_count     score
# 3177       3        1.333333  5.000000
# 3245       5        0.800000  2.600000
# 1015       8        0.500000  1.625000
# 233       14        0.285714  1.214286
# 3977      15        0.266667  0.866667
# ...      ...             ...       ...
# 213     2516        0.001590  0.005564
# 1774    2931        0.001365  0.005459
# 1927    3418        0.001170  0.004681
# 2127    3518        0.001137  0.004264
# 2001    3488        0.001147  0.004014
#
# [568 rows x 9 columns]

# %%
top_movie_recs[top_movie_recs['score'] > 1]
# Out:
#      movieId  count  mean                        title  \
# 3177   68288      2  3.75        Informers, The (2008)
# 3245   70015      2  3.25         Polytechnique (2009)
# 1015  168288      2  3.25  The Belko Experiment (2017)
# 233   111235      2  4.25     Jodorowsky's Dune (2013)
#
#                       genres                clean_title  rating  \
# 3177    Crime|Drama|Thriller         Informers The 2008       3
# 3245             Crime|Drama         Polytechnique 2009       5
# 1015  Action|Horror|Thriller  The Belko Experiment 2017       8
# 233       Documentary|Sci-Fi      Jodorowskys Dune 2013      14
#
#       adjusted_count     score
# 3177        1.333333  5.000000
# 3245        0.800000  2.600000
# 1015        0.500000  1.625000
# 233         0.285714  1.214286
